# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ## Concatenated Dataframe

# %%
# Open saved file and preview again
final2000 = pd.read_csv("Data/final_tmdb_data_2000.csv.gz", low_memory = False)
final2000.info()
final2000.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1216 entries, 0 to 1215
# Data columns (total 26 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   imdb_id                1216 non-null   object
#  1   adult                  1215 non-null   float64
#  2   backdrop_path          651 non-null    object
#  3   belongs_to_collection  111 non-null    object
#  4   budget                 1215 non-null   float64
#  5   genres                 1215 non-null   object
#  6   homepage               66 non-null     object
#  7   id                     1215 non-null   float64
#  8   original_language      1215 non-null   object
#  9   original_title         1215 non-null   object
#  10  overview               1192 non-null   object
#  11  popularity             1215 non-null   float64
#  12  poster_path            1085 non-null   object
#  13  production_companies   1215 non-null   object
#  14  production_countries   1215 non-null   object
#  15  release_date           1207 non-null   object
#  16  revenue                1215 non-null   float64
#  17  runtime                1215 non-null   float64
#  18  spoken_languages       1215 non-null   object
#  19  status                 1215 non-null   object
#  20  tagline                529 non-null    object
#  21  title                  1215 non-null   object
#  22  video                  1215 non-null   float64
#  23  vote_average           1215 non-null   float64
#  24  vote_count             1215 non-null   float64
#  25  certification          380 non-null    object
# dtypes: float64(9), object(17)
# memory usage: 247.1+ KB
#      imdb_id  adult                     backdrop_path belongs_to_collection  \
# 0          0    NaN                               NaN                   NaN
# 1  tt0113026    0.0  /vMFs7nw6P0bIV1jDsQpxAieAVnH.jpg                   NaN
# 2  tt0113092    0.0                               NaN                   NaN
# 3  tt0116391    0.0                               NaN                   NaN
# 4  tt0118694    0.0  /n4GJFGzsc7NinI1VeGDXIcQjtU2.jpg                   NaN
#
#        budget                                             genres homepage  \
# 0         NaN                                                NaN      NaN
# 1  10000000.0  [{'id': 35, 'name': 'Comedy'}, {'id': 10402, '...      NaN
# 2         0.0           [{'id': 878, 'name': 'Science Fiction'}]      NaN
# 3         0.0  [{'id': 18, 'name': 'Drama'}, {'id': 28, 'name...      NaN
# 4    150000.0  [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'n...      NaN
#
#          id original_language   original_title  ...     revenue  runtime  \
# 0       NaN               NaN              NaN  ...         NaN      NaN
# 1   62127.0                en  The Fantasticks  ...         0.0     86.0
# 2  110977.0                en    For the Cause  ...         0.0    100.0
# 3  442869.0                hi             Gang  ...         0.0    152.0
# 4     843.0                cn             花樣年華  ...  12854953.0     99.0
#
#                                     spoken_languages    status  \
# 0                                                NaN       NaN
# 1  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 2  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 3  [{'english_name': 'Hindi', 'iso_639_1': 'hi', ...  Released
# 4  [{'english_name': 'Cantonese', 'iso_639_1': 'c...  Released
#
#                                              tagline                 title  \
# 0                                                NaN                   NaN
# 1      Try to remember the first time magic happened       The Fantasticks
# 2       The ultimate showdown on a forbidden planet.         For the Cause
# 3                                                NaN                  Gang
# 4  Feel the heat, keep the feeling burning, let t...  In the Mood for Love
#
#    video  vote_average vote_count certification
# 0    NaN           NaN        NaN           NaN
# 1    0.0         5.500       22.0           NaN
# 2    0.0         5.100        8.0           NaN
# 3    0.0         4.000        1.0           NaN
# 4    0.0         8.109     2058.0            PG
#
# [5 rows x 26 columns]

# %%
final2001 = pd.read_csv("Data/final_tmdb_data_2001.csv.gz", low_memory = False)
final2001.info()
final2001.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1293 entries, 0 to 1292
# Data columns (total 26 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   imdb_id                1293 non-null   object
#  1   adult                  1292 non-null   float64
#  2   backdrop_path          673 non-null    object
#  3   belongs_to_collection  87 non-null     object
#  4   budget                 1292 non-null   float64
#  5   genres                 1292 non-null   object
#  6   homepage               107 non-null    object
#  7   id                     1292 non-null   float64
#  8   original_language      1292 non-null   object
#  9   original_title         1292 non-null   object
#  10  overview               1263 non-null   object
#  11  popularity             1292 non-null   float64
#  12  poster_path            1147 non-null   object
#  13  production_companies   1292 non-null   object
#  14  production_countries   1292 non-null   object
#  15  release_date           1285 non-null   object
#  16  revenue                1292 non-null   float64
#  17  runtime                1292 non-null   float64
#  18  spoken_languages       1292 non-null   object
#  19  status                 1292 non-null   object
#  20  tagline                537 non-null    object
#  21  title                  1292 non-null   object
#  22  video                  1292 non-null   float64
#  23  vote_average           1292 non-null   float64
#  24  vote_count             1292 non-null   float64
#  25  certification          418 non-null    object
# dtypes: float64(9), object(17)
# memory usage: 262.8+ KB
#      imdb_id  adult                     backdrop_path belongs_to_collection  \
# 0          0    NaN                               NaN                   NaN
# 1  tt0035423    0.0  /hfeiSfWYujh6MKhtGTXyK3DD4nN.jpg                   NaN
# 2  tt0114447    0.0                               NaN                   NaN
# 3  tt0118589    0.0  /9NZAirJahVilTiDNCHLFcdkwkiy.jpg                   NaN
# 4  tt0118652    0.0  /mWxJEFRMvkG4UItYJkRDMgWQ08Y.jpg                   NaN
#
#        budget                                             genres homepage  \
# 0         NaN                                                NaN      NaN
# 1  48000000.0  [{'id': 10749, 'name': 'Romance'}, {'id': 14, ...      NaN
# 2         0.0  [{'id': 53, 'name': 'Thriller'}, {'id': 28, 'n...      NaN
# 3  22000000.0  [{'id': 18, 'name': 'Drama'}, {'id': 10402, 'n...      NaN
# 4   1000000.0  [{'id': 27, 'name': 'Horror'}, {'id': 9648, 'n...      NaN
#
#          id original_language         original_title  ...     revenue  \
# 0       NaN               NaN                    NaN  ...         NaN
# 1   11232.0                en         Kate & Leopold  ...  76019048.0
# 2  151007.0                en       The Silent Force  ...         0.0
# 3   10696.0                en                Glitter  ...   5271666.0
# 4   17140.0                en  The Attic Expeditions  ...         0.0
#
#    runtime                                   spoken_languages    status  \
# 0      NaN                                                NaN       NaN
# 1    118.0  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 2     90.0  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 3    104.0  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 4    100.0  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
#
#                                              tagline                  title  \
# 0                                                NaN                    NaN
# 1  If they lived in the same century, they'd be p...         Kate & Leopold
# 2  They left him for dead... They should have fin...       The Silent Force
# 3   In music she found her dream, her love, herself.                Glitter
# 4  His search for peace of mind... will leave his...  The Attic Expeditions
#
#    video  vote_average vote_count certification
# 0    NaN           NaN        NaN           NaN
# 1    0.0         6.321     1162.0         PG-13
# 2    0.0         5.000        3.0           NaN
# 3    0.0         4.600      118.0         PG-13
# 4    0.0         5.100       28.0             R
#
# [5 rows x 26 columns]

# %%
final_df = pd.concat([final2000, final2001])
final_df.info()
final_df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2509 entries, 0 to 1292
# Data columns (total 26 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   imdb_id                2509 non-null   object
#  1   adult                  2507 non-null   float64
#  2   backdrop_path          1324 non-null   object
#  3   belongs_to_collection  198 non-null    object
#  4   budget                 2507 non-null   float64
#  5   genres                 2507 non-null   object
#  6   homepage               173 non-null    object
#  7   id                     2507 non-null   float64
#  8   original_language      2507 non-null   object
#  9   original_title         2507 non-null   object
#  10  overview               2455 non-null   object
#  11  popularity             2507 non-null   float64
#  12  poster_path            2232 non-null   object
#  13  production_companies   2507 non-null   object
#  14  production_countries   2507 non-null   object
#  15  release_date           2492 non-null   object
#  16  revenue                2507 non-null   float64
#  17  runtime                2507 non-null   float64
#  18  spoken_languages       2507 non-null   object
#  19  status                 2507 non-null   object
#  20  tagline                1066 non-null   object
#  21  title                  2507 non-null   object
#  22  video                  2507 non-null   float64
#  23  vote_average           2507 non-null   float64
#  24  vote_count             2507 non-null   float64
#  25  certification          798 non-null    object
# dtypes: float64(9), object(17)
# memory usage: 529.2+ KB
#      imdb_id  adult                     backdrop_path belongs_to_collection  \
# 0          0    NaN                               NaN                   NaN
# 1  tt0113026    0.0  /vMFs7nw6P0bIV1jDsQpxAieAVnH.jpg                   NaN
# 2  tt0113092    0.0                               NaN                   NaN
# 3  tt0116391    0.0                               NaN                   NaN
# 4  tt0118694    0.0  /n4GJFGzsc7NinI1VeGDXIcQjtU2.jpg                   NaN
#
#        budget                                             genres homepage  \
# 0         NaN                                                NaN      NaN
# 1  10000000.0  [{'id': 35, 'name': 'Comedy'}, {'id': 10402, '...      NaN
# 2         0.0           [{'id': 878, 'name': 'Science Fiction'}]      NaN
# 3         0.0  [{'id': 18, 'name': 'Drama'}, {'id': 28, 'name...      NaN
# 4    150000.0  [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'n...      NaN
#
#          id original_language   original_title  ...     revenue  runtime  \
# 0       NaN               NaN              NaN  ...         NaN      NaN
# 1   62127.0                en  The Fantasticks  ...         0.0     86.0
# 2  110977.0                en    For the Cause  ...         0.0    100.0
# 3  442869.0                hi             Gang  ...         0.0    152.0
# 4     843.0                cn             花樣年華  ...  12854953.0     99.0
#
#                                     spoken_languages    status  \
# 0                                                NaN       NaN
# 1  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 2  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 3  [{'english_name': 'Hindi', 'iso_639_1': 'hi', ...  Released
# 4  [{'english_name': 'Cantonese', 'iso_639_1': 'c...  Released
#
#                                              tagline                 title  \
# 0                                                NaN                   NaN
# 1      Try to remember the first time magic happened       The Fantasticks
# 2       The ultimate showdown on a forbidden planet.         For the Cause
# 3                                                NaN                  Gang
# 4  Feel the heat, keep the feeling burning, let t...  In the Mood for Love
#
#    video  vote_average vote_count certification
# 0    NaN           NaN        NaN           NaN
# 1    0.0         5.500       22.0           NaN
# 2    0.0         5.100        8.0           NaN
# 3    0.0         4.000        1.0           NaN
# 4    0.0         8.109     2058.0            PG
#
# [5 rows x 26 columns]

# %%
FOLDER = "Data/"
final_df.to_csv(f"{FOLDER}tmdb_results_combined.csv.gz", compression="gzip", index=False)

# %% [markdown]
# ## Movies with Valid Financial Info

# %%
budget = (final_df['budget'] > 0)
rev = (final_df['revenue'] > 0)

# %%
filter = (budget | rev)

# %%
filter.value_counts()
# Out:
# False    1882
# True      627
# dtype: int64

# %%
filter.value_counts().plot(kind='bar');

# %% [markdown]
# ## How Many Movies in Each Certification

# %%
final_df['certification'].value_counts()
# Out:
# R          454
# PG-13      182
# NR          67
# PG          63
# G           24
# NC-17        6
# Unrated      1
# -            1
# Name: certification, dtype: int64

# %%
ax = sns.barplot(data = final_df, x = 'certification', y = 'revenue')
ax.bar_label(ax.containers[0])
plt.title("Average Revenue Per Certification");

# %% [markdown]
# ## Average Budget Per Cert Category

# %%
ax = sns.barplot(data = final_df, x = 'certification', y = 'budget')
ax.bar_label(ax.containers[0])
plt.title("Average Budget Per Certification");
